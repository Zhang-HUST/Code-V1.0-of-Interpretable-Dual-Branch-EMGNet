# %% [markdown]
# # This.ipynb file can convert the UCI dataset into training and test sample sets in .npz format
# 1. It is important to point out that the UCI data in.csv format in the '/rawData/' folder is not raw sEMG data. Columns 1-4 show sEMG data preprocessed with z-score normalization: biceps femoris (BF), rectus femoris (RF), vastus medialis (VM), and semitendinosus (SEM), and column 5 is the knee angle in the sagittal plane.
# 2. The use of the UCI dataset includes the Intra-Subject scenario and the Inter-Subject scenario, which the latter in turn contains three different tasks: 'N→N', 'A→A' and 'N→A', and the specific definitions can be referred to our paper.
# 3. More information on the UCI dataset can be found on the website: http://archive.ics.uci.edu/ml/datasets/emg+dataset+in+lower+limb.

# %%
import os
# import sys
# path = os.path.join(os.getcwd())
# sys.path.append(path) 
import math
import numpy as np
import pandas as pd
from utils.tools import make_dir
import warnings
warnings.filterwarnings("ignore")

# %%
## withTransfer=False: the Intra-Subject scenario
#  Return: Target domain subject sample set, label 1 is the motion class, label 2 is the knee joint angle of the upcoming Pl ms.
## withTransfer=True: the Inter-Subject scenario.
#  Return: Source and target domain subject sample sets, label 1 is the motion class, label 2 is the knee joint angle of the upcoming Pl ms.
#  Please refer to our paper for the definition of Pl and the definition of three tasks of 'N→N', 'A→A' and 'N→A'.

class GetSourceTargetDataset:
    def __init__(self, targetSubject, window_length, step, pl_length, withTransfer, task=None, save_flag=False):
        self.withTransfer = withTransfer
        if self.withTransfer:
            self.task = task #'N-N','A-A','N-A'
        self.targetSubject = targetSubject # Target domain subject
        self.window_length = window_length
        self.PredictLength = pl_length # The knee joint angle of the upcoming Pl ms.
        self.Length = self.window_length+self.PredictLength
        self.step = step
        self.motions = ['walking','sitting','standing'] # All motion classes
        self.sub_type = ['N','A'] #  Type of subjects
        self.sub_num = 11 # Number of subjects of the same type
        self.channel = 4 # Number of EMG channels
        self.save_flag = save_flag # Whether to save the sample set

    def return_source_target_sub(self):
        N_list = [''.join([str(i+1),'N']) for i in range(self.sub_num)]
        A_list = [''.join([str(i+1),'A']) for i in range(self.sub_num)]
        if self.task=='N-N':
            temp_list = N_list.copy()
            temp_list.remove(self.targetSubject)
            souSubjects=temp_list
        elif self.task=='A-A':
            temp_list = A_list.copy()
            temp_list.remove(self.targetSubject)
            souSubjects=temp_list
        elif self.task=='N-A':
            souSubjects = N_list
        else:
            raise ValueError('task error!')
        
        return souSubjects

    def get_different_rawdata(self,subject):
        Length, Step, motions, channel = self.Length, self.step, self.motions, self.channel
        Data = []
        MotionLabel = []
        for k in range(len(motions)):
            label = k
            temp0, temp1, temp2 = [], [], []
            file= os.path.join(os.getcwd(), 'rawData', ''.join([subject, motions[k],'.csv']))
            #print(file)
            x = pd.read_csv(file, header=None)
            a=np.array(x.values)
            a[np.isnan(a)] = 0
            a[np.isinf(a)] = 0
            temp0.extend(a)
            length = math.floor((np.array(temp0).shape[0]-Length)/Step)
            temp0=np.array(temp0)
            for j in range(length):
                subSample = temp0[Step*j:(Length+Step*j),:]
                temp1.append(subSample)
                temp2.append(label)
            Data.extend(temp1)
            MotionLabel.extend(temp2)
        Data = np.array(Data)
        MotionLabel = np.array(MotionLabel)
        print('Data.shape: ', Data.shape, ', MotionLabel.shape: ', MotionLabel.shape)
        
        return Data, MotionLabel

    def build(self):
        ## Get the target domain data
        tarSubject = self.targetSubject
        save_flag = self.save_flag
        print('tarSubject: ', tarSubject)
        targetData, targetMotionLabel = self.get_different_rawdata(tarSubject)
        if not self.withTransfer:
            if save_flag:
                target_save_dir=os.path.join(os.getcwd(), 'trainData', 'Intra-Subject')
                make_dir(target_save_dir)
                target_saveName= os.path.join(target_save_dir, ''.join([tarSubject, 'targetTrainData.npz']))
                with open(target_saveName, 'wb') as f:
                    np.savez(f, data=targetData,motionLabel=targetMotionLabel)
            print('targetData: ',targetData.shape, ', targetMotionLabel.shape: ', targetMotionLabel.shape)
        else:
            ## Get the source domain data
            sourceSubjects = self.return_source_target_sub()
            print('sourceSubjects: ', sourceSubjects)
            sourceData, sourceMotionLabel = [], []
            for i in range(len(sourceSubjects)):
                sourceSubject=sourceSubjects[i]
                print('souSubject: ',sourceSubject)
                souData,souMotionLabel=self.get_different_rawdata(sourceSubject)
                sourceData.extend(souData)
                sourceMotionLabel.extend(souMotionLabel)
            sourceData,sourceMotionLabel=np.array(sourceData),np.array(sourceMotionLabel)
            if save_flag:
                if self.task=='N-A':
                    target_save_dir=os.path.join(os.getcwd(), 'trainData', 'Inter-Subject', self.task, 'targetSubjects')
                    make_dir(target_save_dir)
                    source_save_dir=os.path.join(os.getcwd(), 'trainData', 'Inter-Subject', self.task, 'sourceSubjects')
                    make_dir(source_save_dir)
                    target_saveName = os.path.join(target_save_dir, ''.join([tarSubject, 'targetTrainData.npz']))
                    with open(target_saveName, 'wb') as f:
                        np.savez(f, data=targetData, motionLabel=targetMotionLabel)
                    source_saveName= os.path.join(source_save_dir, 'sourceTrainData.npz')
                    if not os.path.isfile(source_saveName):
                        with open(source_saveName, 'wb') as f:
                            np.savez(f, data=sourceData,motionLabel=sourceMotionLabel)
                else:
                    target_save_dir=os.path.join(os.getcwd(), 'trainData', 'Inter-Subject', self.task, 'targetSubjects')
                    make_dir(target_save_dir)
                    target_saveName = os.path.join(target_save_dir, ''.join([tarSubject, 'targetTrainData.npz']))
                    with open(target_saveName, 'wb') as f:
                        np.savez(f, data=targetData,motionLabel=targetMotionLabel)
                    source_save_dir=os.path.join(os.getcwd(),'trainData', 'Inter-Subject', self.task,'sourceSubjects')
                    make_dir(source_save_dir)
                    source_saveName= os.path.join(source_save_dir,''.join([tarSubject, 'sourceTrainData.npz']))
                    with open(source_saveName, 'wb') as f:
                        np.savez(f, data=sourceData, motionLabel=sourceMotionLabel)
            print('targetData.shape: ', targetData.shape, ', targetMotionLabel.shape: ', targetMotionLabel.shape)
            print('sourceData.shape: ', sourceData.shape, ', sourceMotionLabel.shape: ', sourceMotionLabel.shape)

# %%
# Parameter setting
subject_numer = 11
window_length, step_length, pl_length = 256, 64, 64
Nlist = [''.join([str(i+1),'N']) for i in range(subject_numer)]
Alist = [''.join([str(i+1),'A']) for i in range(subject_numer)]
all_sub_lists = Nlist+Alist

# %%
# Intra-Subject sample set generation
for i in range(len(all_sub_lists)):
    targetSubject = all_sub_lists[i]
    print('****'*6 + 'targetSubject: '+ targetSubject +'****'*6)
    GetSourceTargetDataset(targetSubject, window_length, step_length, pl_length, withTransfer=False, task=None, save_flag=True).build()
# Out:
# ************************targetSubject: 1N************************
# tarSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# targetData:  (537, 320, 5) , targetMotionLabel.shape:  (537,)
# ************************targetSubject: 2N************************
# tarSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# targetData:  (565, 320, 5) , targetMotionLabel.shape:  (565,)
# ************************targetSubject: 3N************************
# tarSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData:  (502, 320, 5) , targetMotionLabel.shape:  (502,)
# ************************targetSubject: 4N************************
# tarSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# targetData:  (560, 320, 5) , targetMotionLabel.shape:  (560,)
# ************************targetSubject: 5N************************
# tarSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# targetData:  (532, 320, 5) , targetMotionLabel.shape:  (532,)
# ************************targetSubject: 6N************************
# tarSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# targetData:  (659, 320, 5) , targetMotionLabel.shape:  (659,)
# ************************targetSubject: 7N************************
# tarSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# targetData:  (709, 320, 5) , targetMotionLabel.shape:  (709,)
# ************************targetSubject: 8N************************
# tarSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# targetData:  (789, 320, 5) , targetMotionLabel.shape:  (789,)
# ************************targetSubject: 9N************************
# tarSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# targetData:  (752, 320, 5) , targetMotionLabel.shape:  (752,)
# ************************targetSubject: 10N************************
# tarSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# targetData:  (1107, 320, 5) , targetMotionLabel.shape:  (1107,)
# ************************targetSubject: 11N************************
# tarSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData:  (502, 320, 5) , targetMotionLabel.shape:  (502,)
# ************************targetSubject: 1A************************
# tarSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# targetData:  (626, 320, 5) , targetMotionLabel.shape:  (626,)
# ************************targetSubject: 2A************************
# tarSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# targetData:  (568, 320, 5) , targetMotionLabel.shape:  (568,)
# ************************targetSubject: 3A************************
# tarSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# targetData:  (1618, 320, 5) , targetMotionLabel.shape:  (1618,)
# ************************targetSubject: 4A************************
# tarSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# targetData:  (1858, 320, 5) , targetMotionLabel.shape:  (1858,)
# ************************targetSubject: 5A************************
# tarSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# targetData:  (1402, 320, 5) , targetMotionLabel.shape:  (1402,)
# ************************targetSubject: 6A************************
# tarSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# targetData:  (2549, 320, 5) , targetMotionLabel.shape:  (2549,)
# ************************targetSubject: 7A************************
# tarSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# targetData:  (693, 320, 5) , targetMotionLabel.shape:  (693,)
# ************************targetSubject: 8A************************
# tarSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# targetData:  (631, 320, 5) , targetMotionLabel.shape:  (631,)
# ************************targetSubject: 9A************************
# tarSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# targetData:  (1116, 320, 5) , targetMotionLabel.shape:  (1116,)
# ************************targetSubject: 10A************************
# tarSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# targetData:  (908, 320, 5) , targetMotionLabel.shape:  (908,)
# ************************targetSubject: 11A************************
# tarSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# targetData:  (1112, 320, 5) , targetMotionLabel.shape:  (1112,)

# %%
# Inter-Subject sample set generation
tasks=['N-N', 'A-A', 'N-A']
for k, task in enumerate(tasks):
    if task=='N-N':
        tar_lists = Nlist
    else:
        tar_lists = Alist
    for j, targetSubject in enumerate(tar_lists):
        print('****'*6 + 'task: '+ task + ', targetSubject: '+ targetSubject +'****'*6)
        GetSourceTargetDataset(targetSubject, window_length, step_length, pl_length, withTransfer=True, task=task, save_flag=True).build()
# Out:
# ************************task: N-N, targetSubject: 1N************************
# tarSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# sourceSubjects:  ['2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (537, 320, 5) , targetMotionLabel.shape:  (537,)
# sourceData.shape:  (6677, 320, 5) , sourceMotionLabel.shape:  (6677,)
# ************************task: N-N, targetSubject: 2N************************
# tarSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# sourceSubjects:  ['1N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (565, 320, 5) , targetMotionLabel.shape:  (565,)
# sourceData.shape:  (6649, 320, 5) , sourceMotionLabel.shape:  (6649,)
# ************************task: N-N, targetSubject: 3N************************
# tarSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# sourceSubjects:  ['1N', '2N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (502, 320, 5) , targetMotionLabel.shape:  (502,)
# sourceData.shape:  (6712, 320, 5) , sourceMotionLabel.shape:  (6712,)
# ************************task: N-N, targetSubject: 4N************************
# tarSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# sourceSubjects:  ['1N', '2N', '3N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (560, 320, 5) , targetMotionLabel.shape:  (560,)
# sourceData.shape:  (6654, 320, 5) , sourceMotionLabel.shape:  (6654,)
# ************************task: N-N, targetSubject: 5N************************
# tarSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (532, 320, 5) , targetMotionLabel.shape:  (532,)
# sourceData.shape:  (6682, 320, 5) , sourceMotionLabel.shape:  (6682,)
# ************************task: N-N, targetSubject: 6N************************
# tarSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (659, 320, 5) , targetMotionLabel.shape:  (659,)
# sourceData.shape:  (6555, 320, 5) , sourceMotionLabel.shape:  (6555,)
# ************************task: N-N, targetSubject: 7N************************
# tarSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (709, 320, 5) , targetMotionLabel.shape:  (709,)
# sourceData.shape:  (6505, 320, 5) , sourceMotionLabel.shape:  (6505,)
# ************************task: N-N, targetSubject: 8N************************
# tarSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (789, 320, 5) , targetMotionLabel.shape:  (789,)
# sourceData.shape:  (6425, 320, 5) , sourceMotionLabel.shape:  (6425,)
# ************************task: N-N, targetSubject: 9N************************
# tarSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (752, 320, 5) , targetMotionLabel.shape:  (752,)
# sourceData.shape:  (6462, 320, 5) , sourceMotionLabel.shape:  (6462,)
# ************************task: N-N, targetSubject: 10N************************
# tarSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (1107, 320, 5) , targetMotionLabel.shape:  (1107,)
# sourceData.shape:  (6107, 320, 5) , sourceMotionLabel.shape:  (6107,)
# ************************task: N-N, targetSubject: 11N************************
# tarSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# targetData.shape:  (502, 320, 5) , targetMotionLabel.shape:  (502,)
# sourceData.shape:  (6712, 320, 5) , sourceMotionLabel.shape:  (6712,)
# ************************task: A-A, targetSubject: 1A************************
# tarSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# sourceSubjects:  ['2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A']
# souSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# souSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# souSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# souSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# souSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# souSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# souSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# souSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# souSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# souSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# targetData.shape:  (626, 320, 5) , targetMotionLabel.shape:  (626,)
# sourceData.shape:  (12455, 320, 5) , sourceMotionLabel.shape:  (12455,)
# ************************task: A-A, targetSubject: 2A************************
# tarSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# sourceSubjects:  ['1A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A']
# souSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# souSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# souSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# souSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# souSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# souSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# souSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# souSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# souSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# souSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# targetData.shape:  (568, 320, 5) , targetMotionLabel.shape:  (568,)
# sourceData.shape:  (12513, 320, 5) , sourceMotionLabel.shape:  (12513,)
# ************************task: A-A, targetSubject: 3A************************
# tarSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# sourceSubjects:  ['1A', '2A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A']
# souSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# souSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# souSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# souSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# souSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# souSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# souSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# souSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# souSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# souSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# targetData.shape:  (1618, 320, 5) , targetMotionLabel.shape:  (1618,)
# sourceData.shape:  (11463, 320, 5) , sourceMotionLabel.shape:  (11463,)
# ************************task: A-A, targetSubject: 4A************************
# tarSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# sourceSubjects:  ['1A', '2A', '3A', '5A', '6A', '7A', '8A', '9A', '10A', '11A']
# souSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# souSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# souSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# souSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# souSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# souSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# souSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# souSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# souSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# souSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# targetData.shape:  (1858, 320, 5) , targetMotionLabel.shape:  (1858,)
# sourceData.shape:  (11223, 320, 5) , sourceMotionLabel.shape:  (11223,)
# ************************task: A-A, targetSubject: 5A************************
# tarSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# sourceSubjects:  ['1A', '2A', '3A', '4A', '6A', '7A', '8A', '9A', '10A', '11A']
# souSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# souSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# souSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# souSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# souSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# souSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# souSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# souSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# souSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# souSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# targetData.shape:  (1402, 320, 5) , targetMotionLabel.shape:  (1402,)
# sourceData.shape:  (11679, 320, 5) , sourceMotionLabel.shape:  (11679,)
# ************************task: A-A, targetSubject: 6A************************
# tarSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# sourceSubjects:  ['1A', '2A', '3A', '4A', '5A', '7A', '8A', '9A', '10A', '11A']
# souSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# souSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# souSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# souSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# souSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# souSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# souSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# souSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# souSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# souSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# targetData.shape:  (2549, 320, 5) , targetMotionLabel.shape:  (2549,)
# sourceData.shape:  (10532, 320, 5) , sourceMotionLabel.shape:  (10532,)
# ************************task: A-A, targetSubject: 7A************************
# tarSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# sourceSubjects:  ['1A', '2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A']
# souSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# souSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# souSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# souSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# souSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# souSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# souSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# souSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# souSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# souSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# targetData.shape:  (693, 320, 5) , targetMotionLabel.shape:  (693,)
# sourceData.shape:  (12388, 320, 5) , sourceMotionLabel.shape:  (12388,)
# ************************task: A-A, targetSubject: 8A************************
# tarSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# sourceSubjects:  ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '9A', '10A', '11A']
# souSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# souSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# souSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# souSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# souSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# souSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# souSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# souSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# souSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# souSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# targetData.shape:  (631, 320, 5) , targetMotionLabel.shape:  (631,)
# sourceData.shape:  (12450, 320, 5) , sourceMotionLabel.shape:  (12450,)
# ************************task: A-A, targetSubject: 9A************************
# tarSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# sourceSubjects:  ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '10A', '11A']
# souSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# souSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# souSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# souSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# souSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# souSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# souSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# souSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# souSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# souSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# targetData.shape:  (1116, 320, 5) , targetMotionLabel.shape:  (1116,)
# sourceData.shape:  (11965, 320, 5) , sourceMotionLabel.shape:  (11965,)
# ************************task: A-A, targetSubject: 10A************************
# tarSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# sourceSubjects:  ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '11A']
# souSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# souSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# souSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# souSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# souSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# souSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# souSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# souSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# souSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# souSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# targetData.shape:  (908, 320, 5) , targetMotionLabel.shape:  (908,)
# sourceData.shape:  (12173, 320, 5) , sourceMotionLabel.shape:  (12173,)
# ************************task: A-A, targetSubject: 11A************************
# tarSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# sourceSubjects:  ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A']
# souSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# souSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# souSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# souSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# souSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# souSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# souSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# souSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# souSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# souSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# targetData.shape:  (1112, 320, 5) , targetMotionLabel.shape:  (1112,)
# sourceData.shape:  (11969, 320, 5) , sourceMotionLabel.shape:  (11969,)
# ************************task: N-A, targetSubject: 1A************************
# tarSubject:  1A
# Data.shape:  (626, 320, 5) , MotionLabel.shape:  (626,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (626, 320, 5) , targetMotionLabel.shape:  (626,)
# sourceData.shape:  (7214, 320, 5) , sourceMotionLabel.shape:  (7214,)
# ************************task: N-A, targetSubject: 2A************************
# tarSubject:  2A
# Data.shape:  (568, 320, 5) , MotionLabel.shape:  (568,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (568, 320, 5) , targetMotionLabel.shape:  (568,)
# sourceData.shape:  (7214, 320, 5) , sourceMotionLabel.shape:  (7214,)
# ************************task: N-A, targetSubject: 3A************************
# tarSubject:  3A
# Data.shape:  (1618, 320, 5) , MotionLabel.shape:  (1618,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (1618, 320, 5) , targetMotionLabel.shape:  (1618,)
# sourceData.shape:  (7214, 320, 5) , sourceMotionLabel.shape:  (7214,)
# ************************task: N-A, targetSubject: 4A************************
# tarSubject:  4A
# Data.shape:  (1858, 320, 5) , MotionLabel.shape:  (1858,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (1858, 320, 5) , targetMotionLabel.shape:  (1858,)
# sourceData.shape:  (7214, 320, 5) , sourceMotionLabel.shape:  (7214,)
# ************************task: N-A, targetSubject: 5A************************
# tarSubject:  5A
# Data.shape:  (1402, 320, 5) , MotionLabel.shape:  (1402,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (1402, 320, 5) , targetMotionLabel.shape:  (1402,)
# sourceData.shape:  (7214, 320, 5) , sourceMotionLabel.shape:  (7214,)
# ************************task: N-A, targetSubject: 6A************************
# tarSubject:  6A
# Data.shape:  (2549, 320, 5) , MotionLabel.shape:  (2549,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (2549, 320, 5) , targetMotionLabel.shape:  (2549,)
# sourceData.shape:  (7214, 320, 5) , sourceMotionLabel.shape:  (7214,)
# ************************task: N-A, targetSubject: 7A************************
# tarSubject:  7A
# Data.shape:  (693, 320, 5) , MotionLabel.shape:  (693,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (693, 320, 5) , targetMotionLabel.shape:  (693,)
# sourceData.shape:  (7214, 320, 5) , sourceMotionLabel.shape:  (7214,)
# ************************task: N-A, targetSubject: 8A************************
# tarSubject:  8A
# Data.shape:  (631, 320, 5) , MotionLabel.shape:  (631,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (631, 320, 5) , targetMotionLabel.shape:  (631,)
# sourceData.shape:  (7214, 320, 5) , sourceMotionLabel.shape:  (7214,)
# ************************task: N-A, targetSubject: 9A************************
# tarSubject:  9A
# Data.shape:  (1116, 320, 5) , MotionLabel.shape:  (1116,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (1116, 320, 5) , targetMotionLabel.shape:  (1116,)
# sourceData.shape:  (7214, 320, 5) , sourceMotionLabel.shape:  (7214,)
# ************************task: N-A, targetSubject: 10A************************
# tarSubject:  10A
# Data.shape:  (908, 320, 5) , MotionLabel.shape:  (908,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (908, 320, 5) , targetMotionLabel.shape:  (908,)
# sourceData.shape:  (7214, 320, 5) , sourceMotionLabel.shape:  (7214,)
# ************************task: N-A, targetSubject: 11A************************
# tarSubject:  11A
# Data.shape:  (1112, 320, 5) , MotionLabel.shape:  (1112,)
# sourceSubjects:  ['1N', '2N', '3N', '4N', '5N', '6N', '7N', '8N', '9N', '10N', '11N']
# souSubject:  1N
# Data.shape:  (537, 320, 5) , MotionLabel.shape:  (537,)
# souSubject:  2N
# Data.shape:  (565, 320, 5) , MotionLabel.shape:  (565,)
# souSubject:  3N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# souSubject:  4N
# Data.shape:  (560, 320, 5) , MotionLabel.shape:  (560,)
# souSubject:  5N
# Data.shape:  (532, 320, 5) , MotionLabel.shape:  (532,)
# souSubject:  6N
# Data.shape:  (659, 320, 5) , MotionLabel.shape:  (659,)
# souSubject:  7N
# Data.shape:  (709, 320, 5) , MotionLabel.shape:  (709,)
# souSubject:  8N
# Data.shape:  (789, 320, 5) , MotionLabel.shape:  (789,)
# souSubject:  9N
# Data.shape:  (752, 320, 5) , MotionLabel.shape:  (752,)
# souSubject:  10N
# Data.shape:  (1107, 320, 5) , MotionLabel.shape:  (1107,)
# souSubject:  11N
# Data.shape:  (502, 320, 5) , MotionLabel.shape:  (502,)
# targetData.shape:  (1112, 320, 5) , targetMotionLabel.shape:  (1112,)
# sourceData.shape:  (7214, 320, 5) , sourceMotionLabel.shape:  (7214,)
